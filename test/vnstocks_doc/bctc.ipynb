# %%
# !pip install -U vnstock
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from vnstock import Finance
finance = Finance(symbol='HPG', source='VCI')

# %%
finance.balance_sheet(period='quarter', lang='vi', dropna=True).head(10)
# Out:
#     CP   Năm  Kỳ  TÀI SẢN NGẮN HẠN (đồng)  Tiền và tương đương tiền (đồng)  \
# 0  HPG  2025   4          103682043127964                    8300890304205
# 1  HPG  2025   3           95425988115582                    9092562739415
# 2  HPG  2025   2           97613904938535                   10688024277258
# 3  HPG  2025   1           88914195573724                    7459035818129
# 4  HPG  2024   4           86674276272995                    6887646139852
# 5  HPG  2024   3           80841803394106                    8500998079280
# 6  HPG  2024   2           84466831221789                   13032037853283
# 7  HPG  2024   1           94032457790196                   12428888036237
# 8  HPG  2023   4           82716439173043                   12267401160884
# 9  HPG  2023   3           78482566275784                    9696669423876
#
#    Giá trị thuần đầu tư ngắn hạn (đồng)  Các khoản phải thu ngắn hạn (đồng)  \
# ...

# %%
finance.income_statement(period='quarter', lang='vi', dropna=True).head()
# Out:
#     CP   Năm  Kỳ  Doanh thu (đồng)  Tăng trưởng doanh thu (%)  \
# 0  ACB  2025   4    16080424000000                   0.189523
# 1  ACB  2025   3    15049404000000                   0.164628
# 2  ACB  2025   2    14298695000000                   0.146214
# 3  ACB  2025   1    13327306000000                   0.111758
# 4  ACB  2024   4    13518376000000                   0.080173
#
#    Lợi nhuận sau thuế của Cổ đông công ty mẹ (đồng)  \
# 0                                     2784685000000
# 1                                     4280589000000
# 2                                     4881159000000
# 3                                     3678266000000
# 4                                     4545364000000
#
#    Tăng trưởng lợi nhuận (%)  Thu nhập lãi và các khoản tương tự  \
# 0                  -0.387357                      16080424000000
# 1                   0.105982                      15049404000000
# 2                   0.092326                      14298695000000
# ...

# %%
finance.income_statement(period='quarter', lang='vi', dropna=True).head()
# Out:
#     CP   Năm  Kỳ  Doanh thu (đồng)  Tăng trưởng doanh thu (%)  \
# 0  ACB  2025   4    16080424000000                   0.189523
# 1  ACB  2025   3    15049404000000                   0.164628
# 2  ACB  2025   2    14298695000000                   0.146214
# 3  ACB  2025   1    13327306000000                   0.111758
# 4  ACB  2024   4    13518376000000                   0.080173
#
#    Lợi nhuận sau thuế của Cổ đông công ty mẹ (đồng)  \
# 0                                     2784685000000
# 1                                     4280589000000
# 2                                     4881159000000
# 3                                     3678266000000
# 4                                     4545364000000
#
#    Tăng trưởng lợi nhuận (%)  Thu nhập lãi và các khoản tương tự  \
# 0                  -0.387357                      16080424000000
# 1                   0.105982                      15049404000000
# 2                   0.092326                      14298695000000
# ...
